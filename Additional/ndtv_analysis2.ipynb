# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('ndtv_processed1.csv')

# %%
data
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 1446        1446                   Intex Aqua A2     Intex
# 1447        1447     Videocon Infinium Z51 Nova+  Videocon
# 1448        1448                   Intex Aqua Y4     Intex
# 1449        1449                 iBall Andi4 B20     iBall
# 1450        1450             iBall Andi Avonte 5     iBall
#
#                        Model  Form factor Battery capacity (mAh)  \
# 0     7T Pro McLaren Edition  Touchscreen                   4085
# 1                     X2 Pro  Touchscreen                   4000
# ...

# %%
data.drop(['Processor make'],axis=1,inplace=True)

# %%
data['Operating system'].unique()
# Out:
# array(['Android 10', 'Android 9 Pie', 'iOS 13', 'Android 9',
#        'Android Pie', 'Android 9.0 Pie', 'Android 9.0', 'Android 8.1',
#        'iOS 12', 'Android 8.0', 'Android 8.1 Oreo', 'Android 7.1.1',
#        'iOS 11', 'Android 7.1', 'Android 7.0', 'Android 6.0.1',
#        'Android 6.0', 'iOS 10', 'Android 5.1.1', 'iOS 9',
#        'Cyanogen OS 12', 'Android 5.0', 'Cyanogen OS 11', 'Android 4.3',
#        nan, 'Android Android 9 Pie', 'Android Android 9.0 Pie',
#        'Android 8.0 Oreo', 'Android', 'Android 7.1.2', 'Android 8.0.0',
#        'KAI OS', 'Android 5.1', 'iOS 9.3', 'Android 5.0.2',
#        'Android 4.4.4', 'Android 4.4', 'BlackBerry OS 10.3', 'iOS 8.0',
#        'CyanogenMod 11S', 'Android 4.4.2', 'Android 4.2',
#        'Windows Phone 8', 'iOS 7', 'Android 4.2.2', 'Android 4.1',
#        'Android 4', 'Android 8.1 Oreo (Go edition)', 'Android 8.2 Oreo',
#        'Android Oreo', 'Cyanogen OS 12.1', 'Windows Phone 8.1',
# ...

# %%
data[data['Operating system']!=data['Operating system']]
# Out:
#       Unnamed: 0                Name  Brand           Model  Form factor  \
# 75            75            Vivo V17   Vivo             V17  Touchscreen
# 632          632            Lava Z53   Lava             Z53  Touchscreen
# 710          710    Nokia 106 (2018)  Nokia      106 (2018)          Bar
# 1015        1015  Zen Admire Swadesh    Zen  Admire Swadesh  Touchscreen
# 1286        1286            Lava X11   Lava             X11  Touchscreen
#
#      Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 75                     4500                  6.44         Yes
# 632                    4120                  6.10         NaN
# 710                     800                  1.80          No
# 1015                   2000                  5.00         Yes
# 1286                   2500                  5.00         Yes
#
#             Resolution         Processor  ...  \
# 75    1080x2400 pixels         octa-core  ...
# 632    600x1280 pixels  1.4GHz quad-core  ...
# ...

# %%
data['Operating system'].iloc[75]="Android v9.0 (Pie)"

# %%
data['Operating system'].iloc[632]="Android v9.0 (Pie)"

# %%
data['Operating system'].iloc[710]="Nokia S30"

# %%
data['Operating system'].iloc[1015]="Android 6.0 Marshmallow"

# %%
data['Operating system'].iloc[1286]="Android v5.1 (Lollipop)"

# %%
data[data['Operating system']!=data['Operating system']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Form factor, Battery capacity (mAh), Screen size (inches), Touchscreen, Resolution, Processor, RAM, Internal storage, Rear camera, Front camera, Operating system, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %%
data[data['Front camera']!=data['Front camera']]
# Out:
#      Unnamed: 0              Name   Brand       Model  Form factor  \
# 93           93           Asus 6Z    Asus          6Z  Touchscreen
# 710         710  Nokia 106 (2018)   Nokia  106 (2018)          Bar
# 774         774         Mi Note 5  Xiaomi   Mi Note 5  Touchscreen
#
#     Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 93                    5000                  6.40         Yes
# 710                    800                  1.80          No
# 774                    NaN                  5.99         Yes
#
#            Resolution                                          Processor  ...  \
# 93   1080x2340 pixels  1.8GHz octa-core (4x1.8GHz + 3x2.42GHz + 1x2.8...  ...
# 710    120x160 pixels                                                NaN  ...
# 774               NaN                                          octa-core  ...
#
#                                           Rear camera Front camera  \
# ...

# %%
data['Front camera'].iloc[93]="48-megapixel + 13-megapixel"

# %%
data['Front camera'].iloc[710]="No"

# %%
data['Front camera'].iloc[774]="5-megapixel"

# %%
data['Front camera'].unique()
# Out:
# array(['16-megapixel (f/2.0, 1.0-micron)', '16-megapixel (f/2.0)',
#        '12-megapixel (f/2.2)', '32-megapixel (f/1.9, 0.8-micron)',
#        '10-megapixel (f/2.2)', '24-megapixel',
#        '20-megapixel (f/2.2, 0.8-micron)', '25-megapixel (f/2.0)',
#        '32-megapixel (f/2.0)', '10-megapixel (f/1.9)', '13-megapixel',
#        '10-megapixel (f/1.9) + 8-megapixel (f/2.2)',
#        '24-megapixel (f/2.0)',
#        '8-megapixel (f/1.9, 1.4-micron) + 5-megapixel (f/2.2, 1.4-micron)',
#        '16-megapixel (f/2.0, 1-micron)', '7-megapixel (f/2.2)',
#        '8-megapixel (f/2.2) + 8-megapixel (f/1.8)', '8-megapixel (f/2.0)',
#        '8-megapixel', '8-megapixel (f/1.9)',
#        '8-megapixel (f/2.0, 1.12-micron)',
#        '20-megapixel (f/2.2, 1.0-micron)',
#        '8-megapixel (f/1.7, 1.22-micron)', '7-megapixel', '5-megapixel',
#        '16-megapixel', '4-megapixel (f/2.0, 2-micron)',
#        '5-megapixel (f/1.7, 1.34-micron)',
#        '5-megapixel (f/1.9, 1.34-micron)',
# ...

# %%
data[data['Front camera']!=data['Front camera']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Form factor, Battery capacity (mAh), Screen size (inches), Touchscreen, Resolution, Processor, RAM, Internal storage, Rear camera, Front camera, Operating system, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %%
data[data['Rear camera']!=data['Rear camera']]
# Out:
#      Unnamed: 0              Name   Brand       Model  Form factor  \
# 710         710  Nokia 106 (2018)   Nokia  106 (2018)          Bar
# 774         774         Mi Note 5  Xiaomi   Mi Note 5  Touchscreen
#
#     Battery capacity (mAh)  Screen size (inches) Touchscreen      Resolution  \
# 710                    800                  1.80          No  120x160 pixels
# 774                    NaN                  5.99         Yes             NaN
#
#      Processor  ... Rear camera Front camera Operating system Wi-Fi Bluetooth  \
# 710        NaN  ...         NaN           No        Nokia S30   NaN       NaN
# 774  octa-core  ...         NaN  5-megapixel          Android   NaN       NaN
#
#      GPS Number of SIMs   3G  4G/ LTE    Price
# 710  NaN            NaN  NaN      NaN  ₹ 1,279
# 774  NaN            NaN  NaN      NaN  ₹ 9,399
#
# [2 rows x 22 columns]

# %%
data['Rear camera'].unique()
# Out:
# array(['48-megapixel (f/1.6, 0.8-micron) + 16-megapixel (f/2.2) + 8-megapixel (f/2.4, 1.0-micron)',
#        '64-megapixel (f/1.8) + 13-megapixel (f/2.5) + 8-megapixel (f/2.2) + 2-megapixel',
#        '12-megapixel (f/1.8) + 12-megapixel (f/2.4) + 12-megapixel (f/2.0)',
#        '12-megapixel (f/1.8) + 12-megapixel (f/2.4)',
#        '12-megapixel (f/1.8, 1.4-micron) + 13-megapixel (f/2.4, 1.0-micron)',
#        '48-megapixel (f/1.6, 0.8-micron) + 16-megapixel (f/2.2) + 12-megapixel (f/2.2)',
#        '12-megapixel (f/1.5-2.4) + 16-megapixel (f/2.2) + 12-megapixel (f/2.1) + 0.3-megapixel',
#        '48-megapixel + 13-megapixel',
#        '48-megapixel (f/1.75, 1.6-micron) + 13-megapixel (f/2.4, 1.12-micron) + 8-megapixel (f/2.4, 1.12-micron)',
#        '16-megapixel (f/1.7) + 2-megapixel (f/2.4)',
#        '48-megapixel (f/1.7) + 5-megapixel (f/2.4)',
#        '48-megapixel (f/1.75, 1.6-micron) + 8-megapixel (f/2.4, 1.12-micron) + 13-megapixel (f/2.4, 1.12-micron)',
# ...

# %%
data['Rear camera'].iloc[710]="No"

# %%
data['Rear camera'].iloc[774]="12-megapixel (f/2.2, 1.25-micron)"

# %%
data[data['Rear camera']!=data['Rear camera']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Form factor, Battery capacity (mAh), Screen size (inches), Touchscreen, Resolution, Processor, RAM, Internal storage, Rear camera, Front camera, Operating system, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %%
data[data['Internal storage']!=data['Internal storage']]
# Out:
#       Unnamed: 0                   Name     Brand            Model  \
# 8              8       Asus ROG Phone 2      Asus      ROG Phone 2
# 456          456         Nokia Asha 502     Nokia         Asha 502
# 644          644     Micromax iOne Note  Micromax        iOne Note
# 653          653         Gionee F9 Plus    Gionee          F9 Plus
# 691          691         Coolpad Cool 3   Coolpad           Cool 3
# 726          726       Huawei Y9 (2019)    Huawei        Y9 (2019)
# 1149        1149  Intex Aqua Strong 5.1     Intex  Aqua Strong 5.1
#
#       Form factor Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 8     Touchscreen                   6000                  6.59         Yes
# 456           Bar                   1010                  3.00         Yes
# 644   Touchscreen                   3950                  6.09         Yes
# 653   Touchscreen                   4050                  6.26         Yes
# ...

# %%
data[(data['Internal storage']!=data['Internal storage']) & (data['RAM']!=data['RAM'])]
# Out:
#       Unnamed: 0                   Name     Brand            Model  \
# 644          644     Micromax iOne Note  Micromax        iOne Note
# 691          691         Coolpad Cool 3   Coolpad           Cool 3
# 726          726       Huawei Y9 (2019)    Huawei        Y9 (2019)
# 1149        1149  Intex Aqua Strong 5.1     Intex  Aqua Strong 5.1
#
#       Form factor Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 644   Touchscreen                   3950                  6.09         Yes
# 691           NaN                   3000                  5.71         NaN
# 726           NaN                    NaN                  6.50         NaN
# 1149  Touchscreen                    NaN                   NaN         Yes
#
#            Resolution         Processor  ...                  Rear camera  \
# 644   720x1560 pixels           1.25GHz  ...   13-megapixel + 2-megapixel
# 691   720x1520 pixels  1.3GHz octa-core  ...  8-megapixel + 0.3-megapixel
# ...

# %%
data['Internal storage'].unique()
# Out:
# array(['256GB', '64GB', '128GB', nan, '32GB', '16GB', '8GB', '4GB',
#        '160MB', '3GB', '128MB', '512MB', '512GB', '4MB', '2GB', '1GB'],
#       dtype=object)

# %%
data['Internal storage'].iloc[644]="16GB"
data['RAM'].iloc[644]="2GB"

# %%
data['Internal storage'].iloc[691]="32GB"
data['RAM'].iloc[691]="3GB"

# %%
data['Internal storage'].iloc[726]="64GB"
data['RAM'].iloc[726]="4GB"

# %%
data['Internal storage'].iloc[1149]="8GB"
data['RAM'].iloc[1149]="1GB"

# %%
data[data['Internal storage']!=data['Internal storage']]
# Out:
#      Unnamed: 0              Name   Brand        Model  Form factor  \
# 8             8  Asus ROG Phone 2    Asus  ROG Phone 2  Touchscreen
# 456         456    Nokia Asha 502   Nokia     Asha 502          Bar
# 653         653    Gionee F9 Plus  Gionee      F9 Plus  Touchscreen
#
#     Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 8                     6000                  6.59         Yes
# 456                   1010                  3.00         Yes
# 653                   4050                  6.26         Yes
#
#            Resolution          Processor  ...                  Rear camera  \
# 8    1080x2340 pixels   2.6GHz octa-core  ...  48-megapixel + 13-megapixel
# 456    240x320 pixels           one-core  ...                  5-megapixel
# 653               NaN  1.65GHz octa-core  ...   13-megapixel + 2-megapixel
#
#      Front camera         Operating system Wi-Fi    Bluetooth  GPS  \
# 8    24-megapixel            Android 9 Pie   Yes          Yes  Yes
# ...

# %%
data['Internal storage'].iloc[8]="128GB"
data['Internal storage'].iloc[456]="64MB"
data['Internal storage'].iloc[653]="32GB"

# %%
data[data['Internal storage']!=data['Internal storage']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Form factor, Battery capacity (mAh), Screen size (inches), Touchscreen, Resolution, Processor, RAM, Internal storage, Rear camera, Front camera, Operating system, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %%
data[data['RAM']!=data['RAM']]
# Out:
#       Unnamed: 0                       Name    Brand              Model  \
# 25            25        Apple iPhone XS Max    Apple      iPhone XS Max
# 26            26            Apple iPhone XS    Apple          iPhone XS
# 601          601      Samsung Galaxy Pocket  Samsung      Galaxy Pocket
# 1105        1105  Karbonn Titanium 3-D Plex  Karbonn  Titanium 3-D Plex
#
#       Form factor Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 25    Touchscreen                    NaN                   6.5         Yes
# 26    Touchscreen                    NaN                   5.8         Yes
# 601           Bar                   1200                   2.8         Yes
# 1105  Touchscreen                   2300                   NaN         Yes
#
#             Resolution         Processor  ...  \
# 25    1242x2688 pixels         hexa-core  ...
# 26    1125x2436 pixels         hexa-core  ...
# 601     240x320 pixels  832 MHz one-core  ...
# ...

# %%
data['RAM'].iloc[25]="4GB"
data['Battery capacity (mAh)'].iloc[25]="2658"
data['RAM'].iloc[26]="4GB"
data['Battery capacity (mAh)'].iloc[26]="2658"
data['RAM'].iloc[601]="289MB"
data['RAM'].iloc[1105]="512MB"
data['Resolution'].iloc[1105]="480x854 pixels"
data['Screen size (inches)'].iloc[1105]=5.00

# %%
data[data['RAM']!=data['RAM']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Form factor, Battery capacity (mAh), Screen size (inches), Touchscreen, Resolution, Processor, RAM, Internal storage, Rear camera, Front camera, Operating system, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %%
data[data['Battery capacity (mAh)']!=data['Battery capacity (mAh)']]
# Out:
#       Unnamed: 0                            Name       Brand  \
# 200          200                 Apple iPhone SE       Apple
# 257          257                 Nokia Lumia 920       Nokia
# 726          726                Huawei Y9 (2019)      Huawei
# 774          774                       Mi Note 5      Xiaomi
# 924          924                 Nuu Mobile Q500  Nuu Mobile
# 925          925                 Nuu Mobile Q626  Nuu Mobile
# 962          962           Asus ZenFone 4 Selfie        Asus
# 1004        1004                      Lephone W7     Lephone
# 1149        1149           Intex Aqua Strong 5.1       Intex
# 1270        1270               ZTE Blade V7 Lite         ZTE
# 1331        1331        Micromax Canvas Fire 4G+    Micromax
# 1436        1436  Karbonn Titanium Mach One Plus     Karbonn
#
#                        Model  Form factor Battery capacity (mAh)  \
# 200                iPhone SE  Touchscreen                    NaN
# ...

# %%
data['Battery capacity (mAh)'].iloc[200]="1624"
data['Battery capacity (mAh)'].iloc[257]="2000"
data['Battery capacity (mAh)'].iloc[726]="4000"
data['Battery capacity (mAh)'].iloc[774]="4000"
data['Battery capacity (mAh)'].iloc[924]="2000"
data['Battery capacity (mAh)'].iloc[925]="2000"
data['Battery capacity (mAh)'].iloc[962]="3000"
data['Battery capacity (mAh)'].iloc[1004]="2000"
data['Battery capacity (mAh)'].iloc[1149]="2800"
data['Battery capacity (mAh)'].iloc[1270]="2500"
data['Battery capacity (mAh)'].iloc[1331]="2000"
data['Battery capacity (mAh)'].iloc[1436]="1800"

# %%
data[data['Battery capacity (mAh)']!=data['Battery capacity (mAh)']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Form factor, Battery capacity (mAh), Screen size (inches), Touchscreen, Resolution, Processor, RAM, Internal storage, Rear camera, Front camera, Operating system, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %%
data[data['Screen size (inches)']!=data['Screen size (inches)']]
# Out:
#       Unnamed: 0                                Name      Brand  \
# 716          716  Micromax Bharat 5 Infinity Edition   Micromax
# 905          905                        Panasonic P9  Panasonic
# 1137        1137                   Intex Aqua Eco 4G      Intex
# 1138        1138                  Intex Aqua Viturbo      Intex
# 1149        1149               Intex Aqua Strong 5.1      Intex
#
#                           Model  Form factor Battery capacity (mAh)  \
# 716   Bharat 5 Infinity Edition  Touchscreen                   5000
# 905                          P9  Touchscreen                   2210
# 1137                Aqua Eco 4G  Touchscreen                   1400
# 1138               Aqua Viturbo  Touchscreen                   2000
# 1149            Aqua Strong 5.1  Touchscreen                   2800
#
#       Screen size (inches) Touchscreen      Resolution         Processor  ...  \
# 716                    NaN         Yes             NaN               NaN  ...
# ...

# %%
data['Screen size (inches)'].iloc[716]=5.45
data['Resolution'].iloc[716]="720x1440 pixels"
data['Processor'].iloc[716]="quad-core"
data['Screen size (inches)'].iloc[905]=5.00
data['Screen size (inches)'].iloc[1137]=4.00
data['Resolution'].iloc[1137]="480x800 pixels"
data['Screen size (inches)'].iloc[1138]=4.00
data['Resolution'].iloc[1138]="480x800 pixels"
data['Screen size (inches)'].iloc[1149]=5.00
data['Resolution'].iloc[1149]="480x854 pixels"

# %%
data[data['Screen size (inches)']!=data['Screen size (inches)']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Form factor, Battery capacity (mAh), Screen size (inches), Touchscreen, Resolution, Processor, RAM, Internal storage, Rear camera, Front camera, Operating system, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.to_csv('ndtv_processed2.csv')
